# %% [markdown]
# # Tree Practice

# %%
from pathlib import Path
import sys
import os
from typing import Optional

# %%
cur_path = os.getcwd()
root_dir = Path(cur_path).parent
print(root_dir)
# Out:
# /home/mbarbaric/dev/python/general_python

# %%
sys.path.append(str(root_dir))
sys.path
# Out:
# ['/home/mbarbaric/dev/python/general_python/workbooks',
#  '/usr/lib/python310.zip',
#  '/usr/lib/python3.10',
#  '/usr/lib/python3.10/lib-dynload',
#  '',
#  '/home/mbarbaric/dev/python/general_python/.venv/lib/python3.10/site-packages',
#  '/home/mbarbaric/dev/python/general_python']

# %%
from src.data_structures.trees.tree_node import TreeNode
from src.algos.trees.traversal.iterative_traversal import iterative_inorder_traversal

# %% [markdown]
# ### Maximum Difference Between Node and Ancestor

# %%
root = TreeNode(8)
root.left = TreeNode(3)
root.right = TreeNode(10)
root.left.left = TreeNode(1)
root.left.right = TreeNode(6)
root.left.right.left = TreeNode(4)
root.left.right.right = TreeNode(7)
root.right.right = TreeNode(14)
root.right.right.left = TreeNode(13)

# %%
ans = []
iterative_inorder_traversal(root, ans)

# %%
ans
# Out:
# [1, 3, 4, 6, 7, 8, 10, 13, 14]

# %%
def traverse(root: Optional[TreeNode]):
    if not root:
        return

    print(f"root_node: {root.val}")
    traverse(root.left)
    traverse(root.right)

# %%
traverse(root)
# Out:
# root_node: 8
# root_node: 3
# root_node: 1
# root_node: 6
# root_node: 4
# root_node: 7
# root_node: 10
# root_node: 14
# root_node: 13
