# %% [markdown]
# # Functools

# %% [markdown]
# ### 1.1 @total_ordering
#
# - write the __eq__ and one of __lt__, __le__, __gt__ or __ge__ and the dunder class will take care of the rest.
# - comes with slower execution and more complex stack traces

# %%
from functools import @total_ordering

@total_ordering
class Student(object):
    def __init__(self):
        ...

    def __eq__(self, other: Student):
        ...

    def __lt__(self, other: Student):
        ...
